# %% [markdown]
# <h2>Получаем данные со стены группы VK</h2>

# %%
import glom # для безопасного получения значений словаря
import httpx # для запроса
import pydantic # для парсинга 
import random # для рандомизации временного интервала
import time # для задержки между запросами

from config import access_token, owner_id # настройки для запроса

# %%
def getjson(url, data=None):
    response = httpx.get(url, params=data)
    return response.json()


def get_all_posts(access_token, owner_id, count=100, offset=0):
    """takes access_token, owner_id (group_id), count(default=100), offset(default=0)
    and returns all posts from vk group in a list of dictionaries
    and the number of posts in second variable"""
    all_posts = []
    while True:
        time.sleep(1)
        wall = getjson("https://api.vk.com/method/wall.get", {
            "owner_id" : owner_id,
            "count": count,
            "access_token": access_token,
            "offset": offset,
            "v": '5.131'
        })
        count_posts = wall['response']['count']
        posts = wall['response']['items']

        all_posts.extend(posts)

        if len(all_posts) >= count_posts:
            break
        else:
            offset += 100

    return all_posts, count_posts


def make_posts(all_posts):
    """Takes in a list of dictionaries with posts, converts the data
    in a new structure, returns a new list of dictionaries with the posts"""
    filtered_data = []
    for post in all_posts:
        
        try:
            text = post['text']
        except:
            text = ''

        
        filtered_post = {
            'text': text,
        }
        filtered_data.append(filtered_post)

    return filtered_data
    

all_posts, count_posts = get_all_posts(access_token, owner_id)

pposts = make_posts(all_posts)
for post in pposts:
    print(post['text'], end='\n')
# Out:
# #Python #Программирование #ProgrammingHub
# Просьба ко всем, в комментариях делиться книгами, с вечными ссылками!
# Ставьте хэштеги к книгам! Бесплатная раздача книг (вечные ссылки):
# #Бизли Python. Подробный справочник (Дэвид Бизли 4-е издание):
# https://www.dropbox.com/s/4qzcn3a7pdmhz2p/Bizli_D_-_Python_Podrobny_Spravochnik_4-E_Iz.pdf?dl=0
# #Васильев Python на примерах (Просто о сложном) (Васильев А.Н. - 2016):
# https://www.dropbox.com/s/3vndxclz1v5v9tu/%D0%92%D0%B0%D1%81%D0%B8%D0%BB%D1%8C%D0%B5%D0%B2%20%D0%90.%D0%9D.%20-%20Python%20%D0%BD%D0%B0%20%D0%BF%D1%80%D0%B8%D0%BC%D0%B5%D1%80%D0%B0%D1%85%20%28%D0%9F%D1%80%D0%BE%D1%81%D1%82%D0%BE%20%D0%BE%20%D1%81%D0%BB%D0%BE%D0%B6%D0%BD%D0%BE%D0%BC%29%20-%202016.pdf?dl=0
# #Лутц Лутц М. - Изучаем Python (4-е издание)- 2011.pdf:
# https://www.dropbox.com/s/scj66wlzs0o7txv/%D0%9B%D1%83%D1%82%D1%86%20%D0%9C.%20-%20%D0%98%D0%B7%D1%83%D1%87%D0%B0%D0%B5%D0%BC%20Python%20%284-%D0%B5%20%D0%B8%D0%B7%D0%B4%D0%B0%D0%BD%D0%B8%D0%B5%29-%202011.pdf?dl=0
# #Лутц Марк Лутц - Программирование на Python. (Том 1):
# https://www.dropbox.com/s/sdxnoxj8orcbvpo/%D0%9C%D0%B0%D1%80%D0%BA%20%D0%9B%D1%83%D1%82%D1%86%20-%20%D0%9F%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%20%D0%BD%D0%B0%20Python.%20%D0%A2%D0%BE%D0%BC%201.pdf?dl=0
# #Лутц Марк Лутц - Программирование на Python. (Том 2):
# https://www.dropbox.com/s/90y5nu88cfuv7ew/%D0%9C%D0%B0%D1%80%D0%BA%20%D0%9B%D1%83%D1%82%D1%86%20-%20%D0%9F%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%20%D0%BD%D0%B0%20Python.%20%D0%A2%D0%BE%D0%BC%202.pdf?dl=0
# #Мэтиз Изучаем Python - Эрик Мэтиз:
# https://www.dropbox.com/s/m4w8q9y89vfaejr/%D0%98%D0%B7%D1%83%D1%87%D0%B0%D0%B5%D0%BC%20Python%20-%20%D0%AD%D1%80%D0%B8%D0%BA%20%D0%9C%D1%8D%D1%82%D0%B8%D0%B7.pdf?dl=0
# #Саммерфилд Саммерфилд - Программирование на Python 3.2009.djvu:
# https://www.dropbox.com/s/pbtx0eg1sp0a53s/%D0%A1%D0%B0%D0%BC%D0%BC%D0%B5%D1%80%D1%84%D0%B8%D0%BB%D0%B4%20-%20%D0%9F%D1%80%D0%BE%D0%B3%D1%80%D0%B0%D0%BC%D0%BC%D0%B8%D1%80%D0%BE%D0%B2%D0%B0%D0%BD%D0%B8%D0%B5%20%D0%BD%D0%B0%20Python%203.2009.djvu?dl=0
# #Violent_Python Violent Python - A Cookbook for Hackers, Forensic Analysts, Penetration Testers and Security Engineers:
# https://www.dropbox.com/s/wk731en0j2krkks/Violent%20Python%20-%20A%20Cookbook%20for%20Hackers%2C%20Forensic%20Analysts%2C%20Penetration%20Testers%20and%20Security%20Engineers.pdf?dl=0
# #Web_Scraping Web-Scraping-with-Python.pdf:
# https://www.dropbox.com/s/9wpz3zhd5qmup4x/Web-Scraping-with-Python.pdf?dl=0
# test
# test
# test
# test
# федя лох
# федя лох
# test
# test
# test
# На конкретном примере показана разница между приёмочными и функциональными тестами
# https://www.youtube.com/watch?v=JZQee3j-e2g
# test
# testtest
# Vk give me captcha
# Vk give me captcha
# Vk give me captcha
# Дорогие читатели, уверен, что многие из Вас слышали про бум языка Python за последние годы. И это всё неспроста. Дело в том, что у Python есть много преимуществ, но есть 2 таких, совокупность которых отсутствует у других языков программирования. Во-первых, это простота. Python осваивают даже дети (и даже далеко не старшеклассники). Во-вторых, он обладает огромными возможностями для решения практически любых задач, благодаря колоссальному количеству готовых модулей.
#
# Кто бы мог подумать, что для определения возраста человека по его фотографии (а это безумно сложная задача когда-то была), необходимо всего лишь установить модуль парой кликой мышью, написать несколько строчек кода и готово!
#
# Есть другой пример. Нужно Вам скачать видео в 4K с YouTube. Новички идут покупать программы (бесплатно в таком разрешении скачать затруднительно, по крайней мере, я не нашёл без появляющихся водяных знаков). А программисты на Python могут уже написать простенькую программу на 20-30 строчек кода, которая скачает видео в 4K и бесплатно!
#
# Эти 2 примера подчёркивают и простоту языка, и колоссальные возможности, а потому неудивительно, что Python всё чаще и чаще используется для автоматизации всякой рутины. Но, безусловно, нужно научиться писать такие программы. Как?
#
# И тут я хочу представить Вам курс Михаила Русакова "Написание лайфхаков на Python": https://niksan0099.programsite.ru/pythonlife
#
# Могу смело сказать, что это один из лучших (а на русском языке точно лучший) курсов по Python, что я видел.
#
# До этого курса я уже немного знал Python и мог что-то писать, но как-то не хватало конкретных примеров и практики. Так вот курс мне дал и то, и другое. Так же я в своей работе уже автоматизировал две задаче (и третья в процессе), благодаря полученным знаниям. Благодаря чему теперь регулярно экономлю время!
#
# При этом очень порадовала цена за курс. Обычно у других цены по 50-100 тысяч рублей, а тут кратно меньше, поэтому берите, пока цена не выросла, так как она действительно слишком низкая за такой объём и за такое качество материала.
# Когда-нибудь спрашивали у Яндекса, почему не работает ваш код? Удивлялись, что верный ответ не всегда легко найти? Хотели бы, чтобы поиск Яндекса выдавал самые точные ответы по запросам программистов?
# Если готовы улучшать поиск Яндекса в области программирования, ждём вас в команду асессоров. Нам нужны сотрудники, которые изучают и анализируют выдачу поиска Яндекса. Сейчас мы ищем асессоров с профильным образованием или опытом разработки.
#
# Вы подойдёте, даже если учитесь или стажируетесь, но при условии, что у вас есть реальный опыт написания кода на любом промышленном языке программирования и реализованные проекты.
#
# https://yandex.ru/jobs/vacancies/асессор-разработчик-6130
# Объясняется, что такое покрытие автотестами, как его используют разработчики. А также на конкретном примере показана одна тонкость покрытия
# https://www.youtube.com/watch?v=HkFzLH0g1Gc&t=3s
# https://youtu.be/Ld-gY_Ittak делаю курсы по питону, онлайн репетиторство!
# Друзья, ищу подработку.
# Я программист C++/C#, в основном создавал десктопные приложения (Qt/WinForms).
# Оценить меня можете по этой группе: https://vk.com/byte_machine
# Всех приветствую!
# Разрабатываю программу ByteMachine для анализа и визуализации данных.
# https://vk.com/byte_machine
# На C++, Qt и Python.
# Поддержите
# Новый базовый курс по Python3. Никаких предварительных знаний не требуется!
# Для участников сообщества в течение первых трех дней доступна бесплатная регистрация с пожизненным доступом к курсу.
# Спешите записаться!
#
# https://www.udemy.com/course/python-for-beginners-basics/?couponCode=NEW-PYTHON-100
# Как установить и запустить пример программы по клонированию английской речи
# https://youtu.be/DDskmdYNApo
# Насколько актуальны тестировщики в век глобальной автоматизации? Смогут ли автотесты полностью заменить тестировщиков? В чём отличие автотестов тестировщиков и разработчиков?
# https://www.youtube.com/watch?v=DgGWNxBGmIU
# Влияние автотестов на качество кода.
# На конкретном примере показано влияние unit-тестов и функциональных тестов на качество кода. Пример написан в стиле TDD.
# https://www.youtube.com/watch?v=b8m4PUDophU&t=735s
# https://www.youtube.com/watch?v=LW6GoraFwfY
# Рассмотрены общие принципы написания автотестов для существующего кода любого качества.
# Часть 10: https://www.youtube.com/watch?v=KLZ8q...​
# Делаем тесты частью приложения!
#
# Из статьи вы узнаете:
# - Как написать сотни и тысячи тестов всего в одну строчку
# - Какое новое API отлично бы подошло для Django
# - Что такое "Монадические законы как значения"
#
# Внутри несколько практических примеров как использовать Property-Based тесты для тестироварования ваших приложений. Примеры на Django, deal и dry-python/returns
#
# https://habr.com/ru/post/545646/
# Полный разбор линейной регрессии и методов регуляризации в Python от [club197837145|IT Resume] 💥
#
# Недавно [club197837145|IT Resume] публиковали задачку по методам регуляризации в рубрике GROK IT и все поддержали идею разобрать кейс на эту тему. И вот, разбор уже перед Вами ☺
#
# Это полноценный гайд, в котором мы рассмотрим:
#
# ✓ Как реализовать линейную регрессию в Python
# ✓ Три вида регуляризаций: Lasso, Ridge и ElasticNet
# ✓ Как реализовать регуляризации в Python
# ✓ Как оценить регрессионную модель
# ✓ Какие ограничения существуют у каждого алгоритма
# ✓ Как выбрать подходящий алгоритм
#
# Для тех, кто привык разбираться с алгоритмами, вооружившись кодом, ссылка на notebook 👉🏻 https://bit.ly/38EJTTh
#
# PS. В конце статьи - задачка на самостоятельное изучение, попробуйте 😉 И не забудьте подписаться на [club197837145|IT Resume], будем рады видеть Вас! ☺
#
# #itresume
#
# https://vk.com/@itresume-polnyi-razbor-lineinoi-regressii-i-metodov-regulyarizacii-v
# Здравствуйте, можете подсказать: как совершить обработку события удерживания клавиши мыши? Python 3.7
# Простой практический пример использования преобразования Фурье для восстановления зашумленного аудиосигнала с помощью Python и библиотеки SciPy.
#
# https://proglib.io/p/preobrazovaniya-fure-dlya-obrabotki-signalov-s-pomoshchyu-python-2020-11-03
# Добрый вечер! Подскажите пожалуйста какой компилятор использовать для создания exe из Python? Система -MacOS
# Создание Discord Бота На Python | Бот Для Игры В Города
# Подробная инструкция построения генеративно-состязательных нейросетей (GAN) на примере двух моделей, реализованных с помощью фреймворка глубокого обучения PyTorch.
#
# https://proglib.io/p/generativno-sostyazatelnaya-neyroset-vasha-pervaya-gan-model-na-pytorch-2020-08-11
# Django остаётся самым популярным Python веб-фреймворком в мире, однако архитектура большинства проектов на нём, мягко говоря, оставляет желать лучшего. В этом мастер-классе мы на живом примере поговорим о структуре Django проекта, бизнес-логике в Django, а также о хороших практиках проектирования кода.
# Простое введение в объектно-ориентированное программирование (ООП) на Python. Зачем нужны классы, как их использовать, как инициализировать экземпляр, в чём заключается наследование классов.
#
# https://proglib.io/p/vvedenie-v-obektno-orientirovannoe-programmirovanie-oop-na-python-2020-07-23
# Статья о модуле стандартной библиотеке Python heapq для работы с кучами и очередями с приоритетом. Приведены несколько примеров использования библиотеки для нахождения n оптимальных значений, организации расписания отправки сообщений и поиска кратчайшего пути между двумя точками.
#
# https://proglib.io/p/robot-v-labirinte-obrabatyvaem-ocheredi-s-prioritetom-v-python-2020-07-07
# Часть 10. Функционалные и модульные тесты. Различные цели. Различные подходы.
# Рассматриваются различия целей и подходов при написании функциональных и модульных тестов.
# https://www.youtube.com/watch?v=KLZ8qvbYNUg
# Одна за другой выходят бета-версии Python 3.9. В этой статье на примерах кода разбираются новые возможности. Также добавлены мнения о нововведениях различных разработчиков приложений на Python.
#
# https://proglib.io/p/novye-vozmozhnosti-python-3-9-mneniya-ekspertov-2020-06-12
# Лучшие Ресурсы Для Изучения Django
# Часть 9. Есть ли смысл в трейтах? Как тестировать?
# Объясняется смысл трейтов. Приведён пример тестирования трейта и метода, в котором используется логика трейта. Также поднимается вопрос о целесообразности использования трейтов.
# https://www.youtube.com/watch?v=MI-bn6TjkQY
# Подробное введение в JavaScript для питонистов. Опора на Python позволяет автору через сравнение двух языков быстрее познакомить читателя с разработкой на JS.
#
# https://proglib.io/p/javascript-dlya-python-programmistov-poznanie-cherez-sravnenie-2020-05-29
# Часть 8. Зло ли статика? И как её тестировать? Рассматриваются плюсы и минусы статических методов. На примере предложен вариант тестирования.
# https://www.youtube.com/watch?v=tisHDQzAgN0&t=3s
# Релиз Python 3.9 не за горами — сегодня вышла первая beta версия, а это значит, что весь новый функционал языка уже включён в текущую сборку, а через 5 месяцев выйдет релиз. Python 3.9 идёт в правильную сторону и сегодня мы поговорим о его нововведениях, а также о новшествах от самого Гвидо ван Россума.
# Подробная статья о встроенной функции Python eval(), вопросах ее безопасного и эффективного использования. В конце статьи пошаговое написание программы, обобщающей полученные знания.
#
# https://proglib.io/p/dinamicheskoe-vypolnenie-vyrazheniy-v-python-funkciya-eval-2020-05-14
# Резервное копирование баз данных — всегда актуально. В этом видео показываем и объясняем два Python скрипта, один снимает полный дамп с PostgreSQL, затем архивирует, шифрует и загружает его в Яндекс Object Storage (S3-совместимое хранилище); а второй — выкачивает последний по времени дамп базы из хранилища, расшифровывает его, распаковывает и накатывает на БД.
#
# Видео можно рассматривать как в качестве небольшого практического урока по Python, так и в качестве практического пособия по бэкапу БД или другой информации в облако.
#
# Исходники — https://github.com/alexey-goloburdin/postgres-s3-backuper
# Содержательный туториал об устройстве, назначении и практическом использовании декораторов Python с многочисленными примерами программного кода.
#
# https://proglib.io/p/vse-chto-nuzhno-znat-o-dekoratorah-python-2020-05-09
# Короткий туториал о том, как скачать 390 учебников издательства Springer Nature с помощью 10 строчек кода на Python. Список книг содержит издания по математике, статистике, электронике и Computer Science.
#
# https://proglib.io/p/kak-s-pomoshchyu-python-skachat-vse-besplatnye-uchebniki-springer-nature-2020-05-07
# Часть 7. Ошибки в TDD и последствия
# Описаны часто встречающиеся ошибки при написании модульных тестов, которые совершают не только новички, но и опытные разработчики. Озвучены последствия на конкретных примерах.
# https://www.youtube.com/watch?v=R5fcx_NJCAU
# Всем снова привет! Я продолжаю ролики на тему телеграм ботов и в этом видео покажу, как выложить бота на сервер.
# https://www.youtube.com/watch?v=Yhm189xh6A8
# В этой статье показано, как с помощью модулей pickle и dill хранить и передавать объекты Python со сложной структурой, а также какие проблемы с безопасностью могут возникнуть при десериализации объектов.
#
# https://proglib.io/p/kak-hranit-obekty-python-so-slozhnoy-strukturoy-moduli-pickle-i-dill-2020-04-30
# Краткий туториал по созданию анимированных гифок с визуализацией данных с помощью Python и библиотеки moviepy.
#
# https://proglib.io/p/animaciya-grafikov-v-python-za-4-shaga-2020-04-27
# Всем привет, меня зовут Mr D. Для вас я начал серию видеоуроков по созданию ботов для Telegram на Python. Постарался сделать обучение понятным и насыщенным. Заходите – смотрите!
# https://www.youtube.com/watch?v=CiiBAWuPH5s
# Большая подборка русскоязычных YouTube-каналов и плейлистов, посвящённых различным языкам программирования, включая Python и его фреймворки.
#
# https://proglib.io/p/50-russkoyazychnyh-youtube-kanalov-o-yazykah-programmirovaniya-2020-04-22
# Небольшая улучшалка для тестов. Показан пример использования.
# https://www.youtube.com/watch?v=IBOPrGkJcG4
# Stay Home : Keep Learning With Big Discount
# Learn Ultimate Python-3 GUI Course With Tkinter,Qt and PyGTK Just in 12.99$ 12+ hr Course
# Where you will learn :
# Proficiency in all of the major Tkinter concepts
# Learn Python Basics
# Strong basic fundamentals required to create great GUI
# Learn how to use a wide variety of widgets, such as labels, entries, buttons, spinboxes, and even the Canvas!
# Learn to Build commercial Desktop Applications with Python Tkinter
# Get the most of the sq-lite database for Python projects
# Learn how to use advanced Python functions
# Learn How To Use Qt Designer To Design Your Apps In Less Time
# Learn how to use Signals and Slots in PyQt5
# Learn whats modern in Qt development other done QtWidgets
# Live troubleshooting
# Learn PYGTK
# Learn how to use a wide variety of GTK widgets
# And Much More
# Don't Miss The Chance: Take this course today
# https://www.udemy.com/course/learn-ultimate-python-3-gui-course-with-tkinterqt-and-pygtk/?couponCode=9DFFA4F4A0C0FD11FB90
# В этой подборке собраны бесплатные онлайн-курсы: языки программирования (включая Python), математика для программистов, алгоритмы, анализ данных, веб, мобильная разработка, тестирование и др. Более 70 курсов, все на русском языке. Думаю, будет полезно в условиях карантина.
#
# https://proglib.io/p/superpodborka-bolee-70-besplatnyh-russkoyazychnyh-onlayn-kursov-po-it-specialnostyam-2020-03-25
# На примере показан смысл тестирования закрытых методов. Рассмотрены несколько способов тестирования закрытых методов, оценка скорости выполнения тестов.
# https://www.youtube.com/watch?v=kKvIS4MxXJc
# Пример написание кода в стиле TDD. Разрушаем мифы трудностей освоения TDD.
# https://www.youtube.com/watch?v=SO1AJ-asmw4
#
# 15 вещей, которые нужно знать о словарях Python
#
# Практическое руководство по применению словарей Python. Для профи, хорошо знакомых со структурой dict, бонус об улучшенных словарях в модуле collections и применении словарей в библиотеке pandas.
#
# https://proglib.io/p/15-veshchey-kotorye-nuzhno-znat-o-slovaryah-python-2020-03-03
# 8 характеристик языка программирования Python!
# Здесь уроки — https://vk.cc/apNCke
#
# Это универсальный языка программирования, с которого можно начать освоение программирования. Python обладает очевидными преимуществами, и вот его характеристики:
#
# 1. Кроссплатформенность. Программа, которую Вы напишите на Python, будет прекрасно работать и на Windows, и на Linux, и на Mac OS.
#
# 2. Абсолютно универсален: прикладные программы, Web-программирование, всевозможные скрипты для автоматизации процессов, программирование микроконтроллеров, машинное обучение, анализ big data, игры.
#
# 3. Высокая скорость написания программ, в отличие от тех же Java и C++.
#
# 4. Огромное количество готовых бесплатных библиотек (модулей). Нужно сделать обработку изображения? Подключаем одной строчкой стороннюю библиотеку и просто используем готовые функции. Нужно получить всю информацию о видео, загруженном на YouTube (лайки/дизлайки, просмотры, теги, название, дату загрузки и так далее)? Опять же подключаем библиотеку, вызываем функцию и всё готово.
#
# 5. Используется для написания собственных плагинов, модулей, для автоматизации каких-то задач во множестве программ, включая: Blender, GIMP, Unreal Engine 4 и многие-многие другие.
#
# 6. Используется повсеместно, в том числе, и в крупных компаниях, таких как: Google, Яндекс, Facebook, Mail.ru, NASA, IBM, Instagram и многих других. Как следствие, у этого языка прекрасное будущее и высокая востребованность Python-разработчиков уже сейчас.
#
# 7. Хорошая производительность. Да, она ниже, чем у C++, но при этом выше, чем у PHP, что, в конечном итоге, делает его достаточно популярным при создании Интернет-проектов (например, сервисы Wargaming написаны на Python).
#
# 8. Отлично подходит для первого языка. Недаром, по моим наблюдением, современное поколение детей учат уже не Turbo Pascal (как я когда-то) или Basic, а именно язык Python. И молодцы те родители, которые с детства прививают любовь к программированию, тем более что на Python действительно можно достаточно легко делать сразу интересные для детей вещи, в первую очередь, игры.
#
# А здесь можно изучить Python по бесплатным урокам с упражнениями — https://vk.cc/apNCke
# Наводим порядок на своем жестком диске с помощью Python
# https://youtu.be/HBlcd_lxRFk
# В этой статье рассказано, как связать вместе Python и реляционные базы данных трёх типов: SQLite, MySQL и PostgreSQL. Зная одну библиотеку, вы легко разберетесь в остальных.
#
# https://proglib.io/p/kak-podruzhit-python-i-bazy-dannyh-sql-podrobnoe-rukovodstvo-2020-02-27
# Рассматриваются примеры модульных тестов. Показан один из способов тестирования закрытых методов. Наглядный пример последствий нарушения модульности тестов. Дана рекомендация для упрощения написания модульных тестов. https://www.youtube.com/watch?v=uoyVJSVFc0w
# Настраиваем Vim с помощью небольшого минимального конфига, который можно использовать в повседневной работе. Установим Vundle, несколько плагинов, настроим тему и проведём базовые настройки для удобной работы с кодом в Vim.
# Как научиться программировать?
# Узнай в этом ролике!
#
# Разберем, что делает веб программист на python 3 и vue.js.
# Работаем с github и pycharm. Добавляем новые возможности на сайт.
#
# Особенно полезен данный видос будет тем, кто только начинает изучение программирования и хочет применить свои навыки на практике.
#
# https://youtu.be/g3HwfMb_B-8
# Ребят помогите в развитии моего дс сервера(https://discord.gg/DUqySW2), буду очень вам благодарен
# Модульные тесты (unit-тесты). Проблема и решение изолированности тестируемой логики. Определение mock-объектов, stub-объектов. Отличие mock-ов от stub-ов на примере. https://www.youtube.com/watch?v=6xCOOvrJ8bk&t=11s
#
# Помогите
# Автономные тесты. Интеграционные, функциональные, unit-тесты.
# Все давно уже знают, что такое MVC и согласны с тем, что это хорошо. Но откуда тогда берутся эти проекты с километровым кодом в контроллерах, да ещё и напрямую изменяющим БД? Почему это плохо и как должно быть, а также о главной боли Django — в этом выпуске.
# Посоветуйте курс по пайтону, реальный - не поверхностный. Реально хочу погрузиться в программирование🙏🏻
# В этом видео мы реализуем Телеграм бота для учёта личных расходов с бюджетом, категориями расходов и базовой статистикой. Использовать будем Python и Aiogram с Asyncio, в качестве базы данных легковесный движок SQLite, а результат работы упакуем в Docker контейнер для быстрого разворачивания на любом сервере.
#
# Исходный код на Github: https://github.com/alexey-goloburdin/telegram-finance-bot
# Изучаем классические реляционные базы данных и язык для работы с ними — SQL — на примере топовой открытой СУБД PostgreSQL. Если вас пугает JOIN, вы не понимаете GROUP BY, вас смущает вопрос отличия WHERE от HAVING — смотрите видео полностью и обязательно прорабатывайте все запросы вместе с нами! Мы создадим и изучим работу с базой данных для интернет-магазина, хранящую в себе товары, их фотографии, покупателей и их заказы.
# 9 лучших опенсорс находок за ноябрь 2019
#
# Технологии внутри: Rust, TypeScript, JavaScript, Go, Python.
# Тематика: веб разработка, инструменты для QA, работа с данными, инструменты разработчика и администратора.
#
# https://habr.com/ru/post/478728/
# Поговорим о том, чем хорош Python как технологически, так и в проектном плане с точки зрения наличия специалистов и компаний, использующих технологию.
#
# Тема холиварная, но у нас нет задачи сказать, что все остальные языки плохие, у каждого ЯП есть свои плюсы и выбирать инструмент надо под задачу. Но! Если вам нужен один язык, который вы хотите изучить или с которого хотите начать, вполне вероятно Python — лучший выбор.
#
# Поговорим о принципах разработки Python, о продуманной архитектуре Python, его академичности, быстродействии и выразительности.
# Программирование C / C++ / Java / C# / Python / Delphi / Pascal / VBA;,
# Задачи, Курсовые, Лабораторные, Дипломные работы.
# Онлайн помощь на экзаменах , тестах.
# Создание и разработка веб-сайтов;
# Вёрстка веб-сайтов на технологиях;
# Работа с базами данных: MySQL, Microsoft Access;
# Работа со всеми пакетами Office (Word, Excel, PowerPoint, Access и т.д.);
# Python Programming Assignment Urgent Help Online by Expert Programmers
# Программирование C / C++ / Java / C# / Python / Delphi / Pascal / VBA;,
# Задачи, Курсовые, Лабораторные, Дипломные работы.
# Онлайн помощь на экзаменах , тестах.
# Создание и разработка веб-сайтов;
# Вёрстка веб-сайтов на технологиях;
# Работа с базами данных: MySQL, Microsoft Access;
# Работа со всеми пакетами Office (Word, Excel, PowerPoint, Access и т.д.);
# Новое интервью от АйТиБороды про наш любимый язык.
# Приятного просмотра!
# Программирование на Python с Нуля до Гуру!
# Смотреть подробности — https://vdkurs.programsite.ru/python
#
# Почему именно Python? Это единственный язык программирования, который отлично подходит и для прикладного программирования, и для веб-программирования, и для написания скриптов, автоматизирующих различные процессы, и ещё много для чего.
#
# Так же он отлично подходит для первого языка программирования. И не случайно новое поколение детей учат уже не Turbo Pascal или Basic, а именно язык Python.
#
# И здесь возникает вопрос. Как его выучить с максимальной эффективностью? Чтобы материал был не устаревший, чтобы преподавал его практик, чтобы были упражнения и так далее.
#
# Оптимальным вариантом по изучению Python может стать новый курс Михаила Русакова «Программирование на Python с Нуля до Гуру» — https://vdkurs.programsite.ru/python
# В этом выпуске мы покажем свой шаблон Django проекта с готовой конфигурацией Nginx+Gunicorn+Django+Systemd. Шаблон позволяет стартовать новый проект максимально быстро и не тратить время на редактирование и копирование шаблонных конфигурационных файлов из других проектов.
#
# Шаблон — https://github.com/alexey-goloburdin/django-clean-template
# Python - прекрасный язык программирования, с большим комьюнити по всему миру!
# Вступай в наш открытый чат в телеграмме: https://t.me/python_chat
# Уже в октябре 2019 выходит релиз Python 3.8, а значит самое время познакомиться с его новыми фичами! Заодно обсудим уход Гвидо ван Россума с поста Великодушного Пожизненного Диктатора Python, который произошёл в процессе обсуждения новой функциональности версии 3.8.
#
# Полный официальный перечень обновлений — https://docs.python.org/3.8/whatsnew/3.8.html
# Всем привет, меня зовут Павел и уже более 7 лет я занимаюсь программированием. и IT-консалтингом. Предлагаю вам услуги программистов с ГАРАНТИЕЙ следующего характера:
# Можете обращаться сюда в лс либо вот ссылка на основную страницу vk.com/id522859719 . Здесь же найдете гарантии и отзывы о моих предыдущих работах.
#
# 📌1. Написание программ любой сложности без предоплаты только на Pascal
#
# 📌2. Качественная и быстрая помощь в написании программ, сайтов. Также лабораторные/контрольные/курсовые/дипломы, помощь на экзамене
#
# 📌3. Online-помощь/Консультирование в рамках нашей задачи БЕСПЛАТНО!
#
# 📌4. Ментор. Готов передать свой опыт тому, кто попросит и накормит печенькой.
#
# Помогаю с освоением навыков программирования на следующих языках:
#
# ✔Компьютерная алгебра: Mathcad, Matlab, Maxima, Pcad, Wolfram
#
# С вас сформулированное задание, с меня порядочность и тактичность при выполнении его. К решению прилагается блок-схема, комментарии и отчёт. Постоянным клиентам отчёт к работе бесплатно.
# Любишь Python?
# Вступай в наш чат в телеграмме: https://t.me/python_chat
# Google Таблицы, они же Google Sheets — бесплатный мощный табличный процессор, не уступающий по функционалу Microsoft Excel, доступный на всех платформах из браузера или из родных Google приложений. В этом видео мы покажем, как можно читать и записывать данные в таблицы Google Sheets напрямую из Python проектов.
#
# Консоль Google Developers Console — https://console.developers.google.com/project
#
# Документация Google Sheets API v4 — https://developers.google.com/sheets/
#
# Статья на русском про 4 версию API Google Sheets и её Python обёртку — https://habr.com/ru/post/305378/
#
# Исходники из видео — https://github.com/alexey-goloburdin/youtube-google-sheets-python
# Сложные структуры данных часто возникают в проектах, реализующих сбор и обработку разносортных данных, как правило это многоуровневые вложенные массивы и словари. Работать с такими структурами непросто, но в Python есть отличные встроенные инструменты, позволяющие снизить сложность работы, улучшить читаемость и поддерживаемость кода, облегчить разработку в IDE, а также снизить объём используемой оперативной памяти. В видео мы поговорим о разных подходах и сравним их эффективность — List/Dict, dataclass, tuple, collections.namedtuple, typing.NamedTuple.
# Master Python and Data Science in just 80 minutes
# In this tutorial, you will be learning python and data science from scratch.
# You will be master in operators, strings in python from scratch.
#
# https://www.youtube.com/playlist?list=PLDmvslp_VR0yN2jw6QO9FlVQAjlrDSHg8
# Канал где Senior python developer рассказывает о том как правильно писать код, выкатывает различные статьи о том что сейчас актуально в мире IT
# t.me/Channelpy
# Complete Project in Natural Language Processing on Large Dataset | Python | 90 minutes
# Here, in this complete project of #NLP, you will learn the basic concepts of NLP on large datasets.
# Here, you will learn Python, basics of #Jupyter, #python, how to setup function for modules, GitHub setup, ingest .csv file into SQL and many more. Intermediate experience with python is best.
# Let's get started!
#
# https://youtu.be/8RXlh8hqCQc
# Основы LaTeX для тех, кто ещё не пробовал.
#
# Что такое LaTeX? Это потомок и наследник профессиональной издательской системы, разработанной в 1970х Дональдом Кнутом, автором фундаменального труда «Искусство программирования». К слову, «Искусство программирования» было признано одной из 12 лучших физико-математических монографий 20го века наряду с трудами по теории относительности Альберта Эйнштейна.
#
# LaTeX позволяет из простых текстовых файлов с расширением .tex, содержащих несложную семантику наподобие Markdown или даже HTML (с оговорками, конечно), получать PDF с профессиональной типографикой уровня печатной книги из издательства. Круто? Не то слово! Посмотрим на LaTex подробнее.
#
# LaTex для Windows и Linux — Tex Live, https://www.tug.org/texlive/
# LaTex для MacOS — MacTeX, http://www.tug.org/mactex/
#
# Кроссплатформенный редактор LaTex документов — TeXstudio, https://www.texstudio.org/
# Онлайн редакторы LaTeX:
# * https://www.overleaf.com/
# * https://papeeria.com/
# * https://www.authorea.com/
#
# Курс по LaTex на Coursera от ВШЭ — https://www.coursera.org/learn/latex
#
# Несколько книг по LaTeX на русском языке:
# * «Набор и вёрстка в системе LaTex», С. М. Львовский — https://www.mccme.ru/free-books/llang/newllang.pdf — Львовский
# * «Компьютерная типография LaTeX», Е. М. Балдин — http://mirror.macomnet.net/pub/CTAN/info/russian/Computer_Typesetting_Using_LaTeX/ctex.pdf
# * «LaTeX по-русски», Котельников И.А. — http://www.tex.uniyar.ac.ru/doc/kotelnikovchebotaev2004b.pdf
# Здравствуйте! Уже есть 5-е издание Лутца на русском?
# Настраиваем свой VPN сервер и настраиваем клиент на Mac OS, Windows, Android, iOS. Для чего может понадобиться VPN сервер?
#
# Первый вариант — вы хотите безопасно пользоваться открытыми WiFi сетями в кафе, аэропортах и отелях для того, чтобы обезопасить себя от перехвата важных данных в вашем трафике.
#
# Второй вариант — обход последствий работы Роскомнадзора в России касательно телеграма и в целом. Периодически без VPN не открываются даже сайты с документацией по популярным технологиям.
#
# Третий вариант — получение доступа в локальную (например, офисную) сеть из Интернет. Этот вариант мы пока рассматривать не будем.
#
# Установка:
# wget https://git.io/vpn -O openvpn-install.sh
# sudo bash ./openvpn-install.sh
#
# iOS OpenVPN клиент — https://itunes.apple.com/us/app/openvpn-connect/id590379981?mt=8
# Android OpenVPN клиент — https://play.google.com/store/apps/details?id=net.openvpn.openvpn&hl=en
# Linux OpenVPN клиент — https://openvpn.net/vpn-server-resources/connecting-to-access-server-with-linux/
# Mac OS неофициальный клиент (Tunnelblick) — https://tunnelblick.net/
# Mac OS официальный клиент (но beta) — https://openvpn.net/downloads/openvpn-connect-v3-macos.dmg
# Windows OpenVPN клиент — https://openvpn.net/downloads/openvpn-connect-v3-windows.msi
#
# Официальный сайт OpenVPN — https://openvpn.net/
# Поднимаем с нуля чистый Debian сервер на Яндекс.Облаке (не принципиально — аналогичная настройка будет на Selectel, OVH или любом другом сервисе). Устанавливаем и настраиваем Nginx, Gunicorn, Django приложение, PostgreSQL, Supervisor, а также всю необходимую обвязку для этого. Покажем, как настроить Debian сервер для Django (или любого другого Python WSGI приложения) и связать все компоненты воедино.
# Курс по терминальному мультиплексору tmux. Tmux работает строго в консоли, позволет разбивать окно терминала на несколько панелей, запускать несколько сессий, оставлять их работать в фоне и возвращаться к ним в любой момент. Просто незаменимый инструмент для тех, кто работает в консоли. В серии видео — о том, что такое tmux, основных сценариях его использования и конфигурировании для максимальной скорости и удобства работы с ним.
# Помогаю в написании курсовых, проектных, лабораторных, презентациях, C, Python, Pascal, Эксель. Быстро, качественно, цены ниже средних цен
# Обмен опытом по ЯП pythоn
# https://vk.me/join/AJQ1d1puBgo3sy9tAso7llLd
# Разработка ПО! Решение задач по программированию и курсовых работ, программы для дипломных работ на Java, Python!
# Видео докладов с Python Meetup Chelyabinsk #5
#
# 1. GIL: почему это боль и как с ним жить — Иван Меньших, RaRe Technologies
# 2. Introducing dry-python — Артем Малышев
# 3. Что внутри asyncio — Александр Меренков, Antida software
# 4. Как прокачать линтер — Максим Мазаев, ЦИАН
# 5. Один в поле не воин, или причем тут OSS — Егор Пирогов, 100 Макетов
# В ролике про беседы я упомянул, что получать события из беседы можно 2 способами: Callback API и Longpoll. У Callback API есть ряд недостоинств, например: для его использования необходим сервер, также события обрабатываются не в реальном времени, соответственно страдает скорость. В этом видео разберёмся с Longpoll. В отличие от Callback API, очередь из событий хранится на стороне ВКонтакте — вк не будет присылать отдельное уведомление для каждого события. Также Longpoll можно использовать и на странице с пользователем, в таком случае вместо события сообщества будут обрабатываться действия юзера.
#
# Подробнее в этом видео: https://youtu.be/wPWYiOZJdY4
# 12 и 13 марта в 20.00 разработчиков, особенно Python, ждут на бесплатных онлайн-мероприятиях.
#
# 12 марта – для тех, кто смотрит в сторону Data Science, пройдет открытый вебинар «Метрические алгоритмы классификации». Запишитесь, чтобы не пропустить https://otus.pw/Pqpw/
#
# А 13 марта всех, кто хочет продвинуться на непростом пути Python-программиста, приглашают на онлайн Дня открытых дверей курса для разработчиков «Разработчик Python»: https://otus.pw/bIis/
#
# Кстати, вступительный тест на курс Python проходит всего 30%.
#
# Проверьте, сможете ли вы поступить на курс:
# • онлайн-курс «Data Scientist» https://otus.pw/Dd8K/
# • онлайн-курс «Python» https://otus.pw/cyqM/
#
# Подключайтесь 12 и 13 марта, будет интересно. Готовьте вопросы преподавателям и приходите за подробностями.
# Привет! Написал библиотеку для Python, которая позволяет:
# - делать настоящие приватные методы без нижних подчеркиваний,
# - создавать интерфейсы, методы которого класс не только должен реализовать, но и какие ошибки должны быть ими «брошены» (пример картинке снизу).
#
# Ссылка на библиотеку на Github — https://github.com/dmytrostriletskyi/accessify
# В данном видео будет создан игровой бот(бот, у которого хранятся большое кол-во профилей с внутренней валютой, которую можно заработать путём различных мини-игр). В ходе ролика мы познакомимся с хранением, изменением информации в базе данных(sqlite).
# ~ https://youtu.be/M5FF9qMEWcs ~
# #Программирование - Программирование на С| C++| C#| Java eclipse | php 7версии | MySQL | Python
# #Верстка - html5 | css3 | javascript (vanilla | jquery | ajax)
# Посадка вашего сайта на CMS WordPress, MODx, Textolite.
# 💬Установка JivoSite либо других чатов для вашего сайта!
# ✒Делаю продающий дизайн для лендингов.
# Есть художник, который готов нарисовать для вашего сайта, если что-то потребуется.
# За срыв сроков, по договоренности, возможно снижение цены.
# Портфолио предоставляю по запросу в ЛС.
# В Лабораторию Сбербанка в команду разработки требуются:
#
# * Python Backend разработчик с легкой примесью С/С++
# За спиной опыт работы с системами очередей сообщений, протоколами websockets/WebRTC/Web-push, Flask и веб-серверами.
# Понимание ООП, как реализован pub-sub подход, OWASP уязвимости и как их устранить.
#
# * Python UI разработчик со знанием HTML/CSS/JS
# Опыт разработки UI для Customer Devices как в качестве толстого, так и тонкого клиента. Qt в порядке вещей. Kivy, если хотите поизгаляться над нашим сознанием. Если отрендерите html в Tkinter, приходите, мы просто хотим посмотреть вам в лицо=)
# Понимание работы websockets/WebRTC/Web-push.
#
# * Python/С++ Software Engineer на разработку системного функционала устройства
# Знание Python Standart Library, умение спроектировать и реализовать свой pub-sub механизм, хорошее знание OS Linux и, в частности, cron. Придется также повозиться с железом, системными функциями и решениями наших контрагентов.
#
# Общее для всех. Умение общаться с коллегами, смелость задавать вопросы и проявлять инициативу даже на уровне безумных, как вам кажется, идей. Git, Unit-testing, Docker, Agile прилагаются. Задачи уровня сознательного Middle.
#
# Внимание! Мы – лаборатория, где в полной мере проявится ваша творческая составляющая и свобода выбора действий. Если у вас хватает стрессоустойчивости работать в системе с множеством неизвестных, мужество закрывать эти неизвестные своими желанием и опытом, мы с удовольствием предложим интересные вам условия.
#
# Располагаемся в Москве в 10 минутах от м. Академическая. По всем вопросам пишите в личку или телеграм [id23911942|@mindhatter]. Всем отличного настроения)
#
# #python #вакансия #москва
# Вакансия Python-разработчик
#
# Разыскиваются веб-программисты!
# Наша весёлая и дружная команда ищет разработчиков для проекта системы онлайн обучения и проверки знаний – backend, frontend программистов. Рассматриваем как долгосрочное сотрудничество, так и сдельную работу по конкретному проекту.
#
# Особые приметы:
# - опыт работы с Python (Django), уровень Middle;
# - знание PHP, MySQL-запросов;
# - понимание кроссбраузерной вёрстки (HTML5, jQuery, CSS3);
# - умение работать в команде.
#
# Нашедшемуся:
# - материальное вознаграждение по договоренности;
# - удобное рабочее место в комфортном офисе или работа из дома в свободном графике (на ваш выбор);
# - оформление по ТК;
# - чай, кофе, печеньки.
#
# Вопросы можно задавать мне, предпочтительнее в Telegram [id1972526|@lorchidee]😉
# #Вакансия #Разработчик
# Внимание!!!
# Ищу Django + Vue.JS разработчика на проект https://Kepvi.com
# Желательно из Москвы.
#
# Необходимо доработать целиком функционал по ТЗ, предоставлю в ходе личной беседы.Плюс обеспечу постоянными работами с этим проектом в дальнейшем и необходима будет техническая поддержка на постоянной основе и с самого начала запуска. Доработки и работы по проекту оплачиваются по договоренности.
# За техподдержку, можно получать от чистой прибыли проекта, процент. По мере роста посещаемости, будет солидная сумма.
# Большим плюсом будут навыки разработки ios и android.
# Пиши (если уверен в своих знаниях и навыках)
# в комментах, ЛС группы, скайп: skytalker.neo, или в ЛС: [id4915782|Олег Первый]
# Привет! Пишeм рaбoты рaзличнoй слoжнoсти и в короткие сроки:
# - Языки пpoграммиpoвaния: C/C++, C#, JAVA, php, javascript, T-SQL, Delphi, Pascal, Basic (использую в настоящее врeмя, стaж рaзработок 4 гoда)
# - БД: MS SQL Server MySQL, FireBird , excel, CSS3, прогрaммировaние на arduino, stm32
# - Пaраллeльное прoграммирoвание OpenMP, TBB, MPI
# - Oнлайн-пoмoщь на экзaменах(тoлько зaранее дoговариваемся, дeлаю кyрсовую!Тaкже рaссматриваю вaрианты с пoстоянной работой. Eсть рeзюме на hh.ru.
# Привет ребята, ждём ваши задания. Предлагаем вам следующие услуги :
# 1. Написание программ любой сложности без предоплаты, консультации по языку С++
#
# 2. Качественная и быстрая помощь в написании программ, сайтов. Также лабораторные/контрольные/курсовые/дипломы, помощь на экзамене.
#
# ✔Программирование: C(obj), C++, C#, VBA, Pascal, C++Builder, Delphi7, Basic, Visual Basic. JAVA
#
# ✔Веб: HTML, CSS, JS, PHP7.
# Решаю задачи/курсовые работы/разработка ПО на языках программирования Java, Python, C#, C++ - Выполню за приемлемую цену!
# краткий курс для начинающих по Python от самых азов
# http://itrobo.ru/programmirovanie/kurs-python.html
# Куплю книгу Mark Lutz "Learning Python" 5th edition (на англ.)
# Привет всем! ВАМ Нужна помощь? Пишем для вас работы по программированию различной сложности :
# - Языки программирования и среды: C/C++, C#, JAVA ide, php, javascript, T-SQL, Delphi, Pascal, Basic (использую в настоящее время, +5 лет опыта) AJAX -Решение задач на VB, Excel, Word, C#, Python VB 2018,
# - Базы Данных : MS SQL Server MySQL, FireBird , CSS, Программирование на arduino, stm32. Ввод в эксплуатацию проектов на 1С.
# - Параллельное программирование OpenMP
# Предлагаю помощь СТУДЕНТАМ ( ЛАБОРАТОРНЫЕ, ПРАКТИЧЕСКИЕ, КУРСОВЫЕ, ДИПЛОМНЫЕ ) Пишу колонки на github. Гарантии 100%.
# Добрый день, уважаемые, любите программирование на Python или Java? Нравится ИТМО? Интересуетесь последними новостями в мире IT? Вы за бюджетные технологии и инновации? Или может вам нравится классная музыка?
# Тогда вступайте к нам - в PTCodding! У нас понравится каждому! vk.com/ptcodding
# Здравствуйте. Я - PHP-кодер. Предоставляю услуги в сфере разработки, кейс опыта - 4 года. Портфолио предоставлю.⚠Способен помочь вам в программировании, посоветую-подскажу!
# - Использование Python, Perl, Bash, Delphi скриптов для работы с данными.
# Проекты реализую на Linux/Debian/IOS/Android/win10
# - Опыт работы с SQL, time-series базами данных, нормализацией данных
# Создаю приложения на PHP, использую PHP 7 с Laravel 5
# Есть опыт с реляционными базы данных. MS SQL в качестве основного хранилища, а также используем Redis и RabbitMQ для управления очередями.
# Имеете базовые знания JavaScript. Написание ботов vk|telegram|facebook.
# Пишите, попробуем посотрудничать. Отзывы||Гарантии||Группа по помощи, ссылку в лс
#
# #PHP, #JavaScript, #Ajax, #jQuery, #HTML, #CSS, #MySQL, #js
# Добрый день всем, доброго вечера! Пишу работы под заказ различной сложности:
# - Языки программирования: C/C++, C#, JAVA, php, javascript, T-SQL, Delphi7, Pascal, Basic (использую в настоящее время, 4 года опыта)
# - БД: MS SQL Server MySQL, FireBird , CSS, Программирование микроконтроллеров arduino| stm32| AVR| Pic } Программы на пк и android
# Cборка устройств
# Создание сайтов на Wordpress|Drupal UCOZ под ключ
# Пишите, если актуально, не откажу в консультации по вопросам программирования и ПК
# #Программирование —> на С| C++| C#| Java| php7 | MySQLi | PYTHON
# #Верстка - html5 | css3 | javascript (vanilla | jquery | ajax) Бесплатное тех обслуживание сайтов! 👌
# @Выполняю работы по программированию на языках С/C++||Python||Delphi||Pascal, с использованием Qt, Visual Studio, Borland. Программирую компьютерную графику на OpenGL. Проектирую программы на языке UML. Разрабатываю многопоточные приложения с использованием библиотеки MPI. Пишу программы для обработки больших объемов данных на графических ускорителях от Nvidia с использованием технологии CUDA. 4 года работаю программистом в крупной компании. Работы выполняю уже в течении 5 лет. В цене всегда можно договориться, оплата только после принятия результата работы.
# Добрый день всем! Пишу работы под заказ различной сложности:
# - Языки программирования: C/C++, C#, JAVA, php, javascript, T-SQL, Delphi7, Pascal, Basic (использую в настоящее время, 4 года опыта)
# - БД: MS SQL Server MySQL, FireBird , CSS, программирование на arduino, stm32
# - Параллельное программирование OpenMP, TBB, MPI . Делаю вёрстку, занимаюсь функционалом по psd/ САЙТЫ ПОД 🔑
# - Онлайн-помощь на экзаменах(только заранее договариваемся, делаю курсовую!Имеется группа, вступите!)Жду заказов. Skype dmitrovich.java также рассматриваю варианты с постоянной работой. Есть резюме на hh.ru. Работа с flash, perl, unity 3D,1С! Пишите, коллеги!
# Всем привет! Меня зовут Александр, я опытный программист, который поможет вам написать работу, решить её за вас, или научить писать программы самому.
# Большой спектр услуг:
# - написание программ (Pascal, C, C++, C#, Python, PHP, Mysql, HTML, CSS, JS)
# - разбор ваших программ
# - обучение языкам программирования
# - подготовка к ЕГЭ, ОГЭ и вузовским программам
# - написание сайтов
# Опыт работы более 3 лет.Не стесняйтесь, пишите, всё обсудим)
#
# Вы можете рассчитывать на качественную помощь, оказанную в кратчайшие сроки! Никакой предоплаты! Оплата только после демонстрации выполненной работы.
# Постоянные клиенты или заказы с большим количеством работ получают хорошие скидки!
# Представляю услуги фрилансера. Веб-программист. Ментор.
#  Уверенное знание PHP 5.6;
#  Уверенное владение MySQL;
#  Умение работать с Laravel (Cron Jobs, Queued Jobs);
#  Умение (или желание научиться) работать с GIT;
#  — Глубокие знания JavaScript + jQuery;
#  — Умение работать с legacy кодом;
#  — Любовь к *nix;
#  — Стрессоустойчивость;
# В портфолио есть опыт создания VR/ AR проектов для обучения;
# Поддержка работоспособности систем и модулей;
# Составление и поддержка в актуальном состоянии тех.документации;
# Контроль реализации проекта и ведение отчетности;
# Автоматизация бизнес-процессов организации;
# Хороший алгоритмический базис и понимание архитектуры GPU;
# Опыт работы с git + наличие проектов на Github;
# Дополнительно:
# Беру заказы по Unity 3D/ Visual Studio/ Unreal Engine. Пишите в лс. Есть группа
# Здравствуйте. Есть кто-нибудь, кто зарабатывает на Upwork?
# Get 80% off - Data Visualization with Python: The Complete Guide for Rs 640
#
# Data Scientists are gaining importance and are also earning higher salaries, which means this is the right time to become a data scientist. While, it might seem easy, sorting data, these scientists are responsible for writing important algorithms and programs to help sort and analyze the data – and this isn’t an easy task.
#
# However, we’ve done everything we can to make it as simple as possible. In this beginner course to data visualization, you’ll get started with important concepts of data science. The course will help you understand exactly where to begin in this lucrative field.
#
# https://www.udemy.com/data-visualization-with-python-the-complete-guide/?couponCode=SAUAUG18
# Для тех кто в теме BIG DATA , советую поучаствовать.
# Программист OLP
#
# Инжиниринговая компания ищет программиста в команду реализации проектов 3D-моделирования, симуляции производственных процессов
#
# Санкт-Петербург
#
# Требуемый опыт работы: 3–6 лет
#
# Частичная занятость, гибкий график
#
# Оффлайн программирование роботов. Работа в программных продуктах Visual Components и Delfoi Robotics.
#
# Обязанности:
# Подготовка технической части ТЗ по оффлайн-программированию и дообработке ПО на проекты;
# Проведение калибровки, обучения и оффлайн программирование роботов в программных продуктах Visual Components и Delfoi Robotics;
# Доработка программных продуктов Visual Components и Delfoi Robotics по ТЗ;
# Проведение технических консультаций;
# Выполнение тестовых заданий, проведение технических презентаций и демонстраций программных продуктов и решений;
# Выполнение сертификационных требований вендора (обучение, сдача экзаменов).
#
# Требования:
# Высшее техническое образование;
# Опыт работы с инженерным ПО от 3-х лет;
# Обязательны навыки программирования на Python;
# Опыт работы с CAM-системами – опыт разработки CAM программ;
# Желателен опыт программирования C/C++;
# Хороший уровень английского будет Вашим преимуществом;
# Мотивированность на результат и способность к самоорганизации.
#
# Условия:
# Гибкий график;
# Обучение, тренинги за счет компании;
# Достойный уровень оплаты труда (обсуждается по итогам собеседования);
# В перспективе возможно руководство проектами.
#
# Присылайте резюме или вопросы: vlitun@list.ru или в личку.
# Нужен разработчик на Python в команду на проект по теме недвижимости.
# Есть ещё задачи в области чат-ботов для оптовой торговли и ЖКХ.
# В общем есть огонь-задачи!
# Если ты сам не питонист, скинь это сообщение знакомым питонистам :)
# За подробностями в личку
# Для тех кто занимается ML, советую поучаствоватьи проверить свои возможности.
# Представляю вашему вниманию небольшую игру на Python(pygame) моей разработки.
# Уважаемые, есть кто разбирается в jupiter python? Необходимо сделать прогнозы при помощи моделей ridge и lasso.
# «Когнитивные системы» - компания разработчик нейронных моделей для систем искусственного интеллекта ищет питонистов для прохождения стажировки и/или сдельной работы по проектам с перспективой дальнейшего трудоустройства в штат.
#
# Требования к программистам и стажерам:
#
# -проживание в Москве (при возможности работать как в офисе, так и удаленно);
# -cтуденты страших курсов и выпустившиеся;
# -хорошее знание Python.
# -желание развиваться в сферах искусственного интеллекта, машинного обучения, Big Data, NLP.
#
# В перспективе предстоит работать с технологиями из следующего стека ( не всеми в раз :) :
#
# ...
# Качество звука ни очень, поэтому смотрите с субтитрами.
#
# Подписывайтесь и ставьте лайки, чтобы оставаться в курсе новых видео.
# Эта хорошая книга, что публиковалась здесь ранее, была изъята из публичного доступа. Поэтому выкладываю еще раз. Если что, пишите в личку или в сообщения группы.
#
# Ребят помогите мне в тексте найти цитаты, вот как текст выделенный в скобочках записать в другую переменную.
# my_file = open('text_1.txt', 'r')
# my_string = my_file.read()
# Всем привет!
# С первым днем лета)) Ищу Ведущего разработчика. Удаленная работа, оформление по тк, зп белая, задачи сложные. Сейчас в команде 5 разработчиков (офис, Москва). Ищем удаленного спеца или готового также работать в офисе.
# Полное описание тут http://bit.ly/2qIBu81
#
# #вакансия #удаленнаяработа #удаленно #Python #backbone
#
# Ведущий Python Full-stack developer / удаленно
# ЗП: 160 000
# О НАС:
# Мы разрабатываем серверное ПО, ПО для Hardware, профессиональные решения и сервисы для медиастримминга: IPTV, IP-камер, Broadcasting’а и вебинаров. Наш продукт используют в 100 странах мира. Наши клиенты — это крупные операторы связи, онлайн кинотеатры, операторы видеонаблюдения, гос.структуры, провайдеры и корпорации.
# ЗАДАЧИ:
# Front-end разработка и поддержка web-клиентов (JS+Python), Android и iOS приложений на React Native.
#
# Резюме lmaiv16@gmail.com
# здраствуйте
# я увлекаюсь пайтоном
# подскажите пожалуйста код чтобы был синий экран 1024*768 и него красный контур
# Когда выйдет 5 издание Изучаем Python М.Лутц ?
# Здравствуйте, какой русский видеокурс посоветуете? Главное, чтобы был на русском(с английским плохо), ещё пожалуйста, напишите какие-нибудь сайты с заданиями.
# Спасибо.
# #ПрограммистЮморист #15Год
# Как освоить питон? Хочу в web, big data, machine learning, нейронные сети и в 3D, в частности присоединиться к разработчикам Blender'a. Возможно и в науку. Какие-нибудь книги, курсы. Так же хочу подружиться со специалистами и про-питонистами.
# Подскажите, кто знает, куда можно залить бесплатно простенький сайт (учебный) на джанге?
# #TRACEBACK_GONE_WRONG
# передаем эстафету
# Всем привет! Ищем web-разработчика!
# Компания занимается созданием высоко нагруженных, распределенных систем по анализу и обработке телекоммуникационного трафика. Активно эксплуатируются технологии по работе с BigData и Hiload. ПО работает под управлением Linux и активно взаимодействует с аппаратными средствами для первичного съема трафика.
# Чем Вам придется заниматься:
# 70% времени backend разработка;
# Разработка WEB UI интерфейса;
# Реализация API для использования как WEB UI, так и внешними службами;
# Работа с БД - postgresql (построение и изменение схем, работа с запросами).
# Что мы хотим видеть у Вас:
# Опыт разработки wеб-приложений (клиентской части);
# Владение Python;
# Знание JavaScript, HTML, CSS;
# Понимание технологии AJAX;
# Опыт работы с SQL базами данных.
# Будет Вашим преимуществом, если Вы имеете:
# Опыт работы в Linux;
# Опыт работы с React, Angular2, Ember, Mithril;
# Умение работы в команде.
# Что мы Вам предлагаем:
# Стабильные выплаты "белой" заработной платы;
# Профессиональный, дружный коллектив;
# Интересные задачи;
# Шаговая доступность от метро "Бауманская" (не более 5 минут спокойным шагом), метро "Красносельская" (10 минут);
# Пятидневная рабочая неделя (время начала рабочего дня готовы обсуждать);
# Работа в современном, комфортном офисе;
# Чай, кофе, печенье за счет компании.
#
# Присылайте резюме в л.с.
# Привет! Люди меня постоянно спрашивают про ООП на Python.
#
# Предложи, что на твое усмотрение, может помочь, начинающим, а также и очень опытным пользователям.
#
# Оставь комментарий под этой записью!
# ЛАЙКНИ ИЛИ НАЖМИ ПОДЕЛИТЬСЯ, ЧТОБЫ НЕ ПОТЕРЯТЬ ЭТУ ЗАМЕЧАТЕЛЬНУЮ КНИГУ МАРКА ЛУТЦА!
# #Learning_Python_5th_Edition #Mark Lutz
# Язык: Английский
# Формат: PDF
# 👉Если документ нужен, но вдруг удален по просьбе правообладателя, напиши об этом в сообщения. Отвечу обязательно при первой возможности.
# Лайкни или нажми поделиться, чтобы не потерять!
#  #Python_cookbook от David Beazley
# Язык: Английский
# Формат: PDF
#
# Who This Book Is For:
#
# This book is aimed at more experienced Python programmers who are looking to deepen their understanding of the language and modern programming idioms. Much of the material focuses on some of the more advanced techniques used by libraries, frameworks, and applications.
#
# Throughout the book, the recipes generally assume that the reader already has the necessary background to understand the topic at hand (e.g., general knowledge of computer science, data structures, complexity, systems programming, concurrency, C programming, etc.)
#
# Moreover, the recipes are often just skeletons that aim to provide essential information for getting started, but which require the reader to do more research to fill in the details.
#
# As such, it is assumed that the reader knows how to use search engines
# and Python’s excellent online documentation.
#
# Many of the more advanced recipes will reward the reader’s patience with a much greater insight into how Python actually works under the covers. You will learn new tricks and techniques that can be applied to your own code.
#
# На диплом собрался писать бота для телеграмм (с распознаванием картинок).
#
# Про меня:
# Писал только на C++(Qt), а для этой задачи логичнее использовать что-то "полегче". Питон давно щекочет меня, планирую углубиться в анализ данных и изучить django в прикладных целях.
#
# Учу питон:
# Прошел курс по питону на codecademy, читал про нейросети, смотрю в сторону фреймворка Caffe. Понимаю как работает авторизация по oAuth (писал приложение для vk), принципы REST-архитектуры. Начал читать Лутца.
# Вопрос в том, как вообще реализовать подобное с помощью пайтона? В Qt существует модель сигналов-слотов, посылаю запрос на сервер и жду ответа, в это время приложение "висит". Как это делается в пайтон и какие инструменты мне для этого нужно изучить?
#
# Времени для диплома - 2 месяца, помогите максимально рационально потратить время, параллельно интересуют любые материалы для быстрого старта с django. Благодарю заранее за любую помощь!
# Здравствуйте! Ищу людей, которые как и я, изучают Python для себя, желательно параллельно с английским. У кого есть желание обучаться совместно, пожалуйста напишите в лс!
# Добрый день. Начал изучать программирование с BASH. И так приловчился. Основные задачи по парсингу текста. Можно ли на Питоне реализовать аналоги AWK,SED, или GREP? думаю можно. Но как? было бы очень удобно.
# Конечно же текст можно парсить через цикл.
# Что-то вроде этого
# mydir = os.getcwd()
# my_txt_file = "%s\\temp.txt" % mydir
# f = open(my_txt_file)
# r = f.readlines()
#  for line in r:
#  sp = line.split()
#  if len (sp) != 0:
#  print(sp)
# Но как добавить выборку ( GREP) по нужному элементу списка не зная заранее , какой он будет по счету в списке ?
# КОЛЛЕГИ! Поздравляем всех с праздником!
#
# Страшней оружия, чем IT-ишника нет.
#
# 👍Ставь лайк, если ты согласен!
#
# ✌ Всем кто не с нами, PEACE-DEATH! ✌
# куплю книгу Лутца "изучаем питон" в 4-м издании, недорого 😉
# Касаясь авторизации на сайтах и передачи CSRF-token во время Парсинга.
#
# Мне важны ваши мнения и ответы!
# Часто ли Вы сталкиваетесь со сложностями передачи в Python csrf-токенов и заполнения полей в формах авторизации?
#
# Расскажите с какими сложностями Вы сталкиваетесь?
#
# ПОСТАВЬТЕ ЛАЙК, ЕСЛИ ХОТИТЕ УВИДЕТЬ ВИДЕО-ИНСТРУКЦИЮ НА ЭТУ ТЕМУ.
#
# #Programming_Hub #Python_CSRF #CSRF_TOKEN #PYTHON_PARSING #PYTHON_LOGIN
# 👉 TO BE MASTER, FOLLOW THE MASTER
# Парсинг сайтов в Python. Использование прокси + изменение User-Agent
# Анализ сайтов перед парсингом в Python
# нужен преподаватель по Python..в личку.
# #Python_Без_Загадок
# Хочешь много знать и уметь, тогда надо уметь читать чужой код и разбираться с разными задачами.
#
# Заходи в обсуждения https://vk.com/topic-113913953_35283506 помоги решить задачку, либо выложи свою!
# Как обещано, серия про парсинг еще видео с примером парсинга сайта Авито, а также приемами и методами работы c #Selenium.
# Парсинг данных сайта с помощью #Python и #BeautifulSoup. Работа в многопоточном режиме с помощью #multiprocessing
# Web Development with Django Cookbook
# Автор: Aidas Bendoraitis
# Год: 2014
# Язык: Английский
# Формат: PDF
#
# The Django framework is relatively easy to learn and it solves many web-related questions such as project structure, database object-relational mapping, templating, form validation, sessions, authentication, security, cookies, internationalization, basic administration, creating interfaces to access data from scripts, and more. Django is based on the Python programming language, whose code is clear and easy to read. Django also has a lot of third-party modules that can be used in conjunction with your own apps. Django has an
# established and vibrant community where you can find source code, get help, and contribute.
#
# Django Web Development Cookbook will guide you through all web development processes with the Django 1.6 framework. You will get started with the virtual environment and configuration of the project and then you will learn how to define a database structure with reusable components. After this, you will move on to exploring the forms and views used to enter and list data. Then, you will continue with responsive templates and JavaScript to create the best user experience. After that, you will find out how to tweak the administration to make the website editors happy. You will also learn
# how to integrate your own functionality into Django CMS. The next step will be learning how to use hierarchical structures. Then, you will find out that collecting data from different sources and providing data to others in different formats isn’t as difficult as you thought. And finally, you’ll be introduced to some programming and debugging tricks and will be shown how to deploy the project to a remote dedicated server.
#
# In contrast to other Django books, this book will deal not only with the code of the framework itself, but also with some important third-party modules necessary for fully equipped web development. The book also gives examples of rich user interfaces using the Bootstrap frontend framework and the jQuery JavaScript library.
#
# What this book covers:
#
# Chapter 1 - Getting Started with Django 1.6, will guide you through the basic configuration that is necessary to start any Django project. It will cover topics such as the virtual environment, version control, and project settings.
#
# Chapter 2 - Database Structure, will teach you how to write reusable pieces of code to use in your models. When you create a new app, the first thing to do is to define your models. Also, you will be told how to manage database schema changes using South migrations.
#
# Chapter 3 - Forms and Views, will show you some patterns used to create the views and
# forms for your data.
#
# Chapter 4 - Templates and JavaScript, will show you practical examples of using templates and JavaScript together. We bring together templates and JavaScript because information is always presented to the user by rendered templates and in modern websites, JavaScript is a must for a richer user experience.
#
# Chapter 5 - Custom Template Filters and Tags, will show you how to create and use your own template filters and tags, as the default Django template system is quite extensive, and there are more things to add for different cases.
#
# Chapter 6 - Model Administration, will guide you through extending the default
# administration with your own functionality, as the Django framework comes with a handy prebuilt model administration.
#
# Chapter 7 - Django CMS, deals with the best practices of using Django CMS, which is the most popular open source content management system made with Django, and extending it for your needs.
#
# Chapter 8 - Hierarchical Structures, shows that whenever you need to create a tree-like structure in Django, the django-mptt module comes in handy. This chapter shows you how to use it and how to set administration for hierarchical structures.
#
# Chapter 9 - Data Import and Export, demonstrates to us that very often there are cases when we need to transfer data from and to different formats, and retrieve it from and provide it to different sources. This chapter deals with management commands for data import and also APIs for data export.
#
# Chapter 10 - Bells and Whistles, will show some additional snippets and tricks useful in web development, debugging, and deployment.
# Спасибо за все, что делаете!
# Flask Framework Cookbook
# Автор: Shalabh Aggarwal
# Год: 2014
# Язык: Английский
# Формат: PDF
#
# Flask is a lightweight web application microframework written in Python. It makes use of the flexibility of Python to provide a relatively simple template for web application development.
# Flask makes it possible to write simple one-page applications, but it also has the power to scale them and build larger applications without any issues.
# Flask has excellent documentation and an active community. It has a number of extensions, each of which have documentation that can be rated from good to excellent. There are a few books also available on Flask; they are great and provide a lot of insight into the framework and its applications. This book tries to take a different approach to explain the Flask framework and multiple aspects of its practical uses and applications as a whole.
# This book takes you through a number of recipes that will help you understand the power of Flask and its extensions. You will start by seeing the different configurations that a Flask application can make use of. From here, you will learn how to work with templates, before learning about the ORM and view layers, which act as the foundation of web applications.
# Then, you will learn how to write RESTful APIs with Flask, after learning various authentication techniques. As you move ahead, you will learn how to write an admin interface followed by the debugging and logging of errors in Flask. You will also learn how to make your applications multilingual and gain an insight into the various testing techniques. Finally, you will learn about the different deployment and post-deployment techniques on platforms such as Apache, Tornado, Heroku, and AWS Elastic Beanstalk.
# By the end of this book, you will have all the necessary information required to make the best use of this incredible microframework to write small and big applications and scale them with industry-standard practices.
# A good amount of research coupled with years of experience has been used to develop this book, and I really wish that this book will benefit fellow developers.
# Python Data Science Cookbook -
# Автор: Gopi Subramanian
# Язык: Английский
# Формат: PDF
#
# Более 60 готовых практических решений, которые помогут Вам изучить Python и его огромный потенциал в изучение данных.
#
# Ссылка на код из книжки: https://yadi.sk/d/Xjxk1bXQ37svvu
# Тебе нужны профессиональные книги и  видео на Английском языке?
# Изучаем Python. Программирование игр, визуализация данных, веб-прило­
# жения /Мэтиз Эрик. , 2017.
#
# Книга "Изучаем Python" - это ускоренный курс, который позволит вам сэкономить время и сразу начать писать работоспособные программы (игры, визуализации данных, веб-приложения и многое другое). Хотите стать программистом? В первой части книги вам предстоит узнать о базовых принципах программирования, познакомиться со списками, словарями, классами и циклами, вы научитесь создавать программы и тестировать код. Во второй части книги вы начнете использовать знания на практике, работая над тремя крупными проектами: создадите собственную "стрелялку" с нарастающей сложностью уровней, займетесь работой с большими наборами данных и освоите их визуализацию, и, наконец, создадите полноценное веб-приложение на базе Django, гарантирующее конфиденциальность пользовательской информации.
#  Если вы решились разобраться в том что такое программирование, не нужно ждать. Ключ на старт и вперед!
#
#
#
#
# Из серии книг по программированию на языке Python от Марка Лутца, свое первое знакомство с Python, начните именно с этой книги: "Изучаем Python. 4-е издание"
